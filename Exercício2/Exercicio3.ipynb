# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# !pip install pyproject-toml

# %%
# !pip install fa2
# Out:
# ...
#   Using cached fa2-0.3.5.tar.gz (435 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for fa2
# Failed to build fa2
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [31 lines of output]
#   Installing fa2 package (fastest forceatlas2 python implementation)
#
#   >>>> Cython is installed?
#   Yes
#
#   >>>> Starting to install!
#
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\fa2
#   copying fa2\fa2util.py -> build\lib.win-amd64-cpython-311\fa2
#   copying fa2\forceatlas2.py -> build\lib.win-amd64-cpython-311\fa2
#   copying fa2\__init__.py -> build\lib.win-amd64-cpython-311\fa2
#   running egg_info
#   writing fa2.egg-info\PKG-INFO
#   writing dependency_links to fa2.egg-info\dependency_links.txt
# ...

# %%
G = nx.read_gml("GraphMissingEdges.gml/GraphMissingEdges.gml")

# %%
names = nx.get_node_attributes(G,'name')
print(type(name))
print(name)
# Out:
# <class 'dict'>
# ...

# %%
deg_cen = nx.degree_centrality(G)
nodes = sorted(deg_cen.items(), key=lambda x:x[1], reverse=True)[0:50]
degree_centrality = []
for node in nodes:
    degree_centrality.append({'name': G.nodes[node[0]]['name'], 'category': G.nodes[node[0]]['categories']})

# %%
degree_centrality
# Out:
# [{'name': 'Gaucho Parrilla Argentina', 'category': '221,64,1,83'},
#  {'name': 'Condado Tacos', 'category': '1,393,275,208,58,651'},
#  {'name': 'Noodlehead', 'category': '370,1,620,641'},
#  {'name': 'täkō', 'category': '1,420,651'},
#  {'name': 'Bakersfield', 'category': '58,275,393,208,420,83,651,1'},
#  {'name': 'Smallman Galley', 'category': '275,604,420,173,1,58,641'},
#  {'name': 'Meat & Potatoes', 'category': '428,641,262,490,420,1,188'},
#  {'name': "DiAnoia's Eatery", 'category': '1,287,289,405'},
#  {'name': 'Piada Italian Street Food', 'category': '741,1,405,46'},
#  {'name': 'Banh Mi & Ti', 'category': '1,362,857,204,641'},
#  {'name': 'Pork & Beans',
#   'category': '604,1,208,612,58,275,437,706,133,641,289,613,330'},
#  {'name': 'Social House Seven', 'category': '1,861,791,870,550'},
#  {'name': "Millie's Homemade Ice Cream", 'category': '1,289,641,653'},
#  {'name': 'Southern Tier Brewery Pittsburgh',
#   'category': '58,201,1,100,275,641,188'},
# ...

# %%
df = read_csv('')
