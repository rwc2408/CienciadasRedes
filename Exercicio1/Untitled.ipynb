# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\rodri\anaconda3\lib\site-packages (2.8.4)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
G = nx.Graph()

# %%
G.add_nodes_from(['Albuquerque','Atlanta','Chicago','New York','Pinhais','Curitiba','Miami','Sao Paulo','Londrina','Foz',
                  'Maringa ','Cleveland','Denver','Philadelphia','Minneapolis','Phoenix','Ponta Grossa','Boston','Tulsa'])

# %%
G.add_edges_from([('Albuquerque','Atlanta'),('Chicago','New York'),('Chicago','Pinhais'),
                 ('Curitiba','Atlanta'),('Curitiba','Chicago'),('Curitiba','Miami'),
                 ('Curitiba','New York'),('Curitiba','Sao Paulo'),('Londrina','Foz'),
                 ('Maringa','Albuquerque'),('Maringa','Cleveland'),('Miami','Denver'),
                 ('Miami','New York'),('Miami','Philadelphia'),('Minneapolis','Foz'),
                 ('New York','Cleveland'),('New York','Minneapolis'),('Philadelphia','Atlanta'),
                 ('Phoenix','Cleveland'),('Phoenix','Maringa'),('Pinhais','Londrina'),
                 ('Ponta Grossa','Cleveland'),('Ponta Grossa','Foz'),('Ponta Grossa','Londrina'),
                 ('Sao Paulo','Boston'),('Sao Paulo','Chicago'),('Sao Paulo','Foz'),
                 ('Sao Paulo','Londrina'),('Sao Paulo','Minneapolis'),('Sao Paulo','Ponta Grossa'),
                 ('Tulsa','Maringa'),('Tulsa','New York')])

# %%
nx.draw_networkx(G, with_labels = True)
plt.savefig("atv_01.png")

# %%
list(nx.connected_components(G))
# Out:
# [{'Albuquerque',
#   'Atlanta',
#   'Boston',
#   'Chicago',
#   'Cleveland',
#   'Curitiba',
#   'Denver',
#   'Foz',
#   'Londrina',
#   'Maringa',
#   'Miami',
#   'Minneapolis',
#   'New York',
#   'Philadelphia',
#   'Phoenix',
#   'Pinhais',
#   'Ponta Grossa',
#   'Sao Paulo',
#   'Tulsa'}]

# %%
dict(nx.all_pairs_shortest_path(G))
# Out:
# {'Albuquerque': {'Albuquerque': ['Albuquerque'],
#   'Atlanta': ['Albuquerque', 'Atlanta'],
#   'Maringa': ['Albuquerque', 'Maringa'],
#   'Curitiba': ['Albuquerque', 'Atlanta', 'Curitiba'],
#   'Philadelphia': ['Albuquerque', 'Atlanta', 'Philadelphia'],
#   'Cleveland': ['Albuquerque', 'Maringa', 'Cleveland'],
#   'Phoenix': ['Albuquerque', 'Maringa', 'Phoenix'],
#   'Tulsa': ['Albuquerque', 'Maringa', 'Tulsa'],
#   'Chicago': ['Albuquerque', 'Atlanta', 'Curitiba', 'Chicago'],
#   'Miami': ['Albuquerque', 'Atlanta', 'Curitiba', 'Miami'],
#   'New York': ['Albuquerque', 'Atlanta', 'Curitiba', 'New York'],
#   'Sao Paulo': ['Albuquerque', 'Atlanta', 'Curitiba', 'Sao Paulo'],
#   'Ponta Grossa': ['Albuquerque', 'Maringa', 'Cleveland', 'Ponta Grossa'],
#   'Pinhais': ['Albuquerque', 'Atlanta', 'Curitiba', 'Chicago', 'Pinhais'],
#   'Denver': ['Albuquerque', 'Atlanta', 'Curitiba', 'Miami', 'Denver'],
#   'Minneapolis': ['Albuquerque',
#    'Atlanta',
#    'Curitiba',
#    'New York',
#    'Minneapolis'],
#   'Boston': ['Albuquerque', 'Atlanta', 'Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Albuquerque', 'Atlanta', 'Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Albuquerque', 'Atlanta', 'Curitiba', 'Sao Paulo', 'Londrina']},
#  'Atlanta': {'Atlanta': ['Atlanta'],
#   'Albuquerque': ['Atlanta', 'Albuquerque'],
#   'Curitiba': ['Atlanta', 'Curitiba'],
#   'Philadelphia': ['Atlanta', 'Philadelphia'],
#   'Maringa': ['Atlanta', 'Albuquerque', 'Maringa'],
#   'Chicago': ['Atlanta', 'Curitiba', 'Chicago'],
#   'Miami': ['Atlanta', 'Curitiba', 'Miami'],
#   'New York': ['Atlanta', 'Curitiba', 'New York'],
#   'Sao Paulo': ['Atlanta', 'Curitiba', 'Sao Paulo'],
#   'Cleveland': ['Atlanta', 'Albuquerque', 'Maringa', 'Cleveland'],
#   'Phoenix': ['Atlanta', 'Albuquerque', 'Maringa', 'Phoenix'],
#   'Tulsa': ['Atlanta', 'Albuquerque', 'Maringa', 'Tulsa'],
#   'Pinhais': ['Atlanta', 'Curitiba', 'Chicago', 'Pinhais'],
#   'Denver': ['Atlanta', 'Curitiba', 'Miami', 'Denver'],
#   'Minneapolis': ['Atlanta', 'Curitiba', 'New York', 'Minneapolis'],
#   'Boston': ['Atlanta', 'Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Atlanta', 'Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Atlanta', 'Curitiba', 'Sao Paulo', 'Londrina'],
#   'Ponta Grossa': ['Atlanta', 'Curitiba', 'Sao Paulo', 'Ponta Grossa']},
#  'Chicago': {'Chicago': ['Chicago'],
#   'New York': ['Chicago', 'New York'],
#   'Pinhais': ['Chicago', 'Pinhais'],
#   'Curitiba': ['Chicago', 'Curitiba'],
#   'Sao Paulo': ['Chicago', 'Sao Paulo'],
#   'Miami': ['Chicago', 'New York', 'Miami'],
#   'Cleveland': ['Chicago', 'New York', 'Cleveland'],
#   'Minneapolis': ['Chicago', 'New York', 'Minneapolis'],
#   'Tulsa': ['Chicago', 'New York', 'Tulsa'],
#   'Londrina': ['Chicago', 'Pinhais', 'Londrina'],
#   'Atlanta': ['Chicago', 'Curitiba', 'Atlanta'],
#   'Boston': ['Chicago', 'Sao Paulo', 'Boston'],
#   'Foz': ['Chicago', 'Sao Paulo', 'Foz'],
#   'Ponta Grossa': ['Chicago', 'Sao Paulo', 'Ponta Grossa'],
#   'Denver': ['Chicago', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Chicago', 'New York', 'Miami', 'Philadelphia'],
#   'Maringa': ['Chicago', 'New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Chicago', 'New York', 'Cleveland', 'Phoenix'],
#   'Albuquerque': ['Chicago', 'Curitiba', 'Atlanta', 'Albuquerque']},
#  'New York': {'New York': ['New York'],
#   'Chicago': ['New York', 'Chicago'],
#   'Curitiba': ['New York', 'Curitiba'],
#   'Miami': ['New York', 'Miami'],
#   'Cleveland': ['New York', 'Cleveland'],
#   'Minneapolis': ['New York', 'Minneapolis'],
#   'Tulsa': ['New York', 'Tulsa'],
#   'Pinhais': ['New York', 'Chicago', 'Pinhais'],
#   'Sao Paulo': ['New York', 'Chicago', 'Sao Paulo'],
#   'Atlanta': ['New York', 'Curitiba', 'Atlanta'],
#   'Denver': ['New York', 'Miami', 'Denver'],
#   'Philadelphia': ['New York', 'Miami', 'Philadelphia'],
#   'Maringa': ['New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['New York', 'Cleveland', 'Phoenix'],
#   'Ponta Grossa': ['New York', 'Cleveland', 'Ponta Grossa'],
#   'Foz': ['New York', 'Minneapolis', 'Foz'],
#   'Londrina': ['New York', 'Chicago', 'Pinhais', 'Londrina'],
#   'Boston': ['New York', 'Chicago', 'Sao Paulo', 'Boston'],
#   'Albuquerque': ['New York', 'Curitiba', 'Atlanta', 'Albuquerque']},
#  'Pinhais': {'Pinhais': ['Pinhais'],
#   'Chicago': ['Pinhais', 'Chicago'],
#   'Londrina': ['Pinhais', 'Londrina'],
#   'New York': ['Pinhais', 'Chicago', 'New York'],
#   'Curitiba': ['Pinhais', 'Chicago', 'Curitiba'],
#   'Sao Paulo': ['Pinhais', 'Chicago', 'Sao Paulo'],
#   'Foz': ['Pinhais', 'Londrina', 'Foz'],
#   'Ponta Grossa': ['Pinhais', 'Londrina', 'Ponta Grossa'],
#   'Miami': ['Pinhais', 'Chicago', 'New York', 'Miami'],
#   'Cleveland': ['Pinhais', 'Chicago', 'New York', 'Cleveland'],
#   'Minneapolis': ['Pinhais', 'Chicago', 'New York', 'Minneapolis'],
#   'Tulsa': ['Pinhais', 'Chicago', 'New York', 'Tulsa'],
#   'Atlanta': ['Pinhais', 'Chicago', 'Curitiba', 'Atlanta'],
#   'Boston': ['Pinhais', 'Chicago', 'Sao Paulo', 'Boston'],
#   'Denver': ['Pinhais', 'Chicago', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Pinhais', 'Chicago', 'New York', 'Miami', 'Philadelphia'],
#   'Maringa': ['Pinhais', 'Chicago', 'New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Pinhais', 'Chicago', 'New York', 'Cleveland', 'Phoenix'],
#   'Albuquerque': ['Pinhais', 'Chicago', 'Curitiba', 'Atlanta', 'Albuquerque']},
#  'Curitiba': {'Curitiba': ['Curitiba'],
#   'Atlanta': ['Curitiba', 'Atlanta'],
#   'Chicago': ['Curitiba', 'Chicago'],
#   'Miami': ['Curitiba', 'Miami'],
#   'New York': ['Curitiba', 'New York'],
#   'Sao Paulo': ['Curitiba', 'Sao Paulo'],
#   'Albuquerque': ['Curitiba', 'Atlanta', 'Albuquerque'],
#   'Philadelphia': ['Curitiba', 'Atlanta', 'Philadelphia'],
#   'Pinhais': ['Curitiba', 'Chicago', 'Pinhais'],
#   'Denver': ['Curitiba', 'Miami', 'Denver'],
#   'Cleveland': ['Curitiba', 'New York', 'Cleveland'],
#   'Minneapolis': ['Curitiba', 'New York', 'Minneapolis'],
#   'Tulsa': ['Curitiba', 'New York', 'Tulsa'],
#   'Boston': ['Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Curitiba', 'Sao Paulo', 'Londrina'],
#   'Ponta Grossa': ['Curitiba', 'Sao Paulo', 'Ponta Grossa'],
#   'Maringa': ['Curitiba', 'Atlanta', 'Albuquerque', 'Maringa'],
#   'Phoenix': ['Curitiba', 'New York', 'Cleveland', 'Phoenix']},
#  'Miami': {'Miami': ['Miami'],
#   'Curitiba': ['Miami', 'Curitiba'],
#   'Denver': ['Miami', 'Denver'],
#   'New York': ['Miami', 'New York'],
#   'Philadelphia': ['Miami', 'Philadelphia'],
#   'Atlanta': ['Miami', 'Curitiba', 'Atlanta'],
#   'Chicago': ['Miami', 'Curitiba', 'Chicago'],
#   'Sao Paulo': ['Miami', 'Curitiba', 'Sao Paulo'],
#   'Cleveland': ['Miami', 'New York', 'Cleveland'],
#   'Minneapolis': ['Miami', 'New York', 'Minneapolis'],
#   'Tulsa': ['Miami', 'New York', 'Tulsa'],
#   'Albuquerque': ['Miami', 'Curitiba', 'Atlanta', 'Albuquerque'],
#   'Pinhais': ['Miami', 'Curitiba', 'Chicago', 'Pinhais'],
#   'Boston': ['Miami', 'Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Miami', 'Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Miami', 'Curitiba', 'Sao Paulo', 'Londrina'],
#   'Ponta Grossa': ['Miami', 'Curitiba', 'Sao Paulo', 'Ponta Grossa'],
#   'Maringa': ['Miami', 'New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Miami', 'New York', 'Cleveland', 'Phoenix']},
#  'Sao Paulo': {'Sao Paulo': ['Sao Paulo'],
#   'Curitiba': ['Sao Paulo', 'Curitiba'],
#   'Boston': ['Sao Paulo', 'Boston'],
#   'Chicago': ['Sao Paulo', 'Chicago'],
#   'Foz': ['Sao Paulo', 'Foz'],
#   'Londrina': ['Sao Paulo', 'Londrina'],
#   'Minneapolis': ['Sao Paulo', 'Minneapolis'],
#   'Ponta Grossa': ['Sao Paulo', 'Ponta Grossa'],
#   'Atlanta': ['Sao Paulo', 'Curitiba', 'Atlanta'],
#   'Miami': ['Sao Paulo', 'Curitiba', 'Miami'],
#   'New York': ['Sao Paulo', 'Curitiba', 'New York'],
#   'Pinhais': ['Sao Paulo', 'Chicago', 'Pinhais'],
#   'Cleveland': ['Sao Paulo', 'Ponta Grossa', 'Cleveland'],
#   'Albuquerque': ['Sao Paulo', 'Curitiba', 'Atlanta', 'Albuquerque'],
#   'Philadelphia': ['Sao Paulo', 'Curitiba', 'Atlanta', 'Philadelphia'],
#   'Denver': ['Sao Paulo', 'Curitiba', 'Miami', 'Denver'],
#   'Tulsa': ['Sao Paulo', 'Curitiba', 'New York', 'Tulsa'],
#   'Maringa': ['Sao Paulo', 'Ponta Grossa', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Sao Paulo', 'Ponta Grossa', 'Cleveland', 'Phoenix']},
#  'Londrina': {'Londrina': ['Londrina'],
#   'Foz': ['Londrina', 'Foz'],
#   'Pinhais': ['Londrina', 'Pinhais'],
#   'Ponta Grossa': ['Londrina', 'Ponta Grossa'],
#   'Sao Paulo': ['Londrina', 'Sao Paulo'],
#   'Minneapolis': ['Londrina', 'Foz', 'Minneapolis'],
#   'Chicago': ['Londrina', 'Pinhais', 'Chicago'],
#   'Cleveland': ['Londrina', 'Ponta Grossa', 'Cleveland'],
#   'Curitiba': ['Londrina', 'Sao Paulo', 'Curitiba'],
#   'Boston': ['Londrina', 'Sao Paulo', 'Boston'],
#   'New York': ['Londrina', 'Foz', 'Minneapolis', 'New York'],
#   'Maringa': ['Londrina', 'Ponta Grossa', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Londrina', 'Ponta Grossa', 'Cleveland', 'Phoenix'],
#   'Atlanta': ['Londrina', 'Sao Paulo', 'Curitiba', 'Atlanta'],
#   'Miami': ['Londrina', 'Sao Paulo', 'Curitiba', 'Miami'],
#   'Tulsa': ['Londrina', 'Foz', 'Minneapolis', 'New York', 'Tulsa'],
#   'Albuquerque': ['Londrina',
#    'Ponta Grossa',
#    'Cleveland',
#    'Maringa',
#    'Albuquerque'],
#   'Philadelphia': ['Londrina',
#    'Sao Paulo',
#    'Curitiba',
#    'Atlanta',
#    'Philadelphia'],
#   'Denver': ['Londrina', 'Sao Paulo', 'Curitiba', 'Miami', 'Denver']},
#  'Foz': {'Foz': ['Foz'],
#   'Londrina': ['Foz', 'Londrina'],
#   'Minneapolis': ['Foz', 'Minneapolis'],
#   'Ponta Grossa': ['Foz', 'Ponta Grossa'],
#   'Sao Paulo': ['Foz', 'Sao Paulo'],
#   'Pinhais': ['Foz', 'Londrina', 'Pinhais'],
#   'New York': ['Foz', 'Minneapolis', 'New York'],
#   'Cleveland': ['Foz', 'Ponta Grossa', 'Cleveland'],
#   'Curitiba': ['Foz', 'Sao Paulo', 'Curitiba'],
#   'Boston': ['Foz', 'Sao Paulo', 'Boston'],
#   'Chicago': ['Foz', 'Sao Paulo', 'Chicago'],
#   'Miami': ['Foz', 'Minneapolis', 'New York', 'Miami'],
#   'Tulsa': ['Foz', 'Minneapolis', 'New York', 'Tulsa'],
#   'Maringa': ['Foz', 'Ponta Grossa', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Foz', 'Ponta Grossa', 'Cleveland', 'Phoenix'],
#   'Atlanta': ['Foz', 'Sao Paulo', 'Curitiba', 'Atlanta'],
#   'Denver': ['Foz', 'Minneapolis', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Foz', 'Minneapolis', 'New York', 'Miami', 'Philadelphia'],
#   'Albuquerque': ['Foz',
#    'Ponta Grossa',
#    'Cleveland',
#    'Maringa',
#    'Albuquerque']},
#  'Maringa': {'Maringa': ['Maringa'],
#   'Albuquerque': ['Maringa', 'Albuquerque'],
#   'Cleveland': ['Maringa', 'Cleveland'],
#   'Phoenix': ['Maringa', 'Phoenix'],
#   'Tulsa': ['Maringa', 'Tulsa'],
#   'Atlanta': ['Maringa', 'Albuquerque', 'Atlanta'],
#   'New York': ['Maringa', 'Cleveland', 'New York'],
#   'Ponta Grossa': ['Maringa', 'Cleveland', 'Ponta Grossa'],
#   'Curitiba': ['Maringa', 'Albuquerque', 'Atlanta', 'Curitiba'],
#   'Philadelphia': ['Maringa', 'Albuquerque', 'Atlanta', 'Philadelphia'],
#   'Chicago': ['Maringa', 'Cleveland', 'New York', 'Chicago'],
#   'Miami': ['Maringa', 'Cleveland', 'New York', 'Miami'],
#   'Minneapolis': ['Maringa', 'Cleveland', 'New York', 'Minneapolis'],
#   'Foz': ['Maringa', 'Cleveland', 'Ponta Grossa', 'Foz'],
#   'Londrina': ['Maringa', 'Cleveland', 'Ponta Grossa', 'Londrina'],
#   'Sao Paulo': ['Maringa', 'Cleveland', 'Ponta Grossa', 'Sao Paulo'],
#   'Pinhais': ['Maringa', 'Cleveland', 'New York', 'Chicago', 'Pinhais'],
#   'Denver': ['Maringa', 'Cleveland', 'New York', 'Miami', 'Denver'],
#   'Boston': ['Maringa', 'Cleveland', 'Ponta Grossa', 'Sao Paulo', 'Boston']},
#  'Cleveland': {'Cleveland': ['Cleveland'],
#   'Maringa': ['Cleveland', 'Maringa'],
#   'New York': ['Cleveland', 'New York'],
#   'Phoenix': ['Cleveland', 'Phoenix'],
#   'Ponta Grossa': ['Cleveland', 'Ponta Grossa'],
#   'Albuquerque': ['Cleveland', 'Maringa', 'Albuquerque'],
#   'Tulsa': ['Cleveland', 'Maringa', 'Tulsa'],
#   'Chicago': ['Cleveland', 'New York', 'Chicago'],
#   'Curitiba': ['Cleveland', 'New York', 'Curitiba'],
#   'Miami': ['Cleveland', 'New York', 'Miami'],
#   'Minneapolis': ['Cleveland', 'New York', 'Minneapolis'],
#   'Foz': ['Cleveland', 'Ponta Grossa', 'Foz'],
#   'Londrina': ['Cleveland', 'Ponta Grossa', 'Londrina'],
#   'Sao Paulo': ['Cleveland', 'Ponta Grossa', 'Sao Paulo'],
#   'Atlanta': ['Cleveland', 'Maringa', 'Albuquerque', 'Atlanta'],
#   'Pinhais': ['Cleveland', 'New York', 'Chicago', 'Pinhais'],
#   'Denver': ['Cleveland', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Cleveland', 'New York', 'Miami', 'Philadelphia'],
#   'Boston': ['Cleveland', 'Ponta Grossa', 'Sao Paulo', 'Boston']},
#  'Denver': {'Denver': ['Denver'],
#   'Miami': ['Denver', 'Miami'],
#   'Curitiba': ['Denver', 'Miami', 'Curitiba'],
#   'New York': ['Denver', 'Miami', 'New York'],
#   'Philadelphia': ['Denver', 'Miami', 'Philadelphia'],
#   'Atlanta': ['Denver', 'Miami', 'Curitiba', 'Atlanta'],
#   'Chicago': ['Denver', 'Miami', 'Curitiba', 'Chicago'],
#   'Sao Paulo': ['Denver', 'Miami', 'Curitiba', 'Sao Paulo'],
#   'Cleveland': ['Denver', 'Miami', 'New York', 'Cleveland'],
#   'Minneapolis': ['Denver', 'Miami', 'New York', 'Minneapolis'],
#   'Tulsa': ['Denver', 'Miami', 'New York', 'Tulsa'],
#   'Albuquerque': ['Denver', 'Miami', 'Curitiba', 'Atlanta', 'Albuquerque'],
#   'Pinhais': ['Denver', 'Miami', 'Curitiba', 'Chicago', 'Pinhais'],
#   'Boston': ['Denver', 'Miami', 'Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Denver', 'Miami', 'Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Denver', 'Miami', 'Curitiba', 'Sao Paulo', 'Londrina'],
#   'Ponta Grossa': ['Denver', 'Miami', 'Curitiba', 'Sao Paulo', 'Ponta Grossa'],
#   'Maringa': ['Denver', 'Miami', 'New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Denver', 'Miami', 'New York', 'Cleveland', 'Phoenix']},
#  'Philadelphia': {'Philadelphia': ['Philadelphia'],
#   'Miami': ['Philadelphia', 'Miami'],
#   'Atlanta': ['Philadelphia', 'Atlanta'],
#   'Curitiba': ['Philadelphia', 'Miami', 'Curitiba'],
#   'Denver': ['Philadelphia', 'Miami', 'Denver'],
#   'New York': ['Philadelphia', 'Miami', 'New York'],
#   'Albuquerque': ['Philadelphia', 'Atlanta', 'Albuquerque'],
#   'Chicago': ['Philadelphia', 'Miami', 'Curitiba', 'Chicago'],
#   'Sao Paulo': ['Philadelphia', 'Miami', 'Curitiba', 'Sao Paulo'],
#   'Cleveland': ['Philadelphia', 'Miami', 'New York', 'Cleveland'],
#   'Minneapolis': ['Philadelphia', 'Miami', 'New York', 'Minneapolis'],
#   'Tulsa': ['Philadelphia', 'Miami', 'New York', 'Tulsa'],
#   'Maringa': ['Philadelphia', 'Atlanta', 'Albuquerque', 'Maringa'],
#   'Pinhais': ['Philadelphia', 'Miami', 'Curitiba', 'Chicago', 'Pinhais'],
#   'Boston': ['Philadelphia', 'Miami', 'Curitiba', 'Sao Paulo', 'Boston'],
#   'Foz': ['Philadelphia', 'Miami', 'Curitiba', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Philadelphia', 'Miami', 'Curitiba', 'Sao Paulo', 'Londrina'],
#   'Ponta Grossa': ['Philadelphia',
#    'Miami',
#    'Curitiba',
#    'Sao Paulo',
#    'Ponta Grossa'],
#   'Phoenix': ['Philadelphia', 'Miami', 'New York', 'Cleveland', 'Phoenix']},
#  'Minneapolis': {'Minneapolis': ['Minneapolis'],
#   'Foz': ['Minneapolis', 'Foz'],
#   'New York': ['Minneapolis', 'New York'],
#   'Sao Paulo': ['Minneapolis', 'Sao Paulo'],
#   'Londrina': ['Minneapolis', 'Foz', 'Londrina'],
#   'Ponta Grossa': ['Minneapolis', 'Foz', 'Ponta Grossa'],
#   'Chicago': ['Minneapolis', 'New York', 'Chicago'],
#   'Curitiba': ['Minneapolis', 'New York', 'Curitiba'],
#   'Miami': ['Minneapolis', 'New York', 'Miami'],
#   'Cleveland': ['Minneapolis', 'New York', 'Cleveland'],
#   'Tulsa': ['Minneapolis', 'New York', 'Tulsa'],
#   'Boston': ['Minneapolis', 'Sao Paulo', 'Boston'],
#   'Pinhais': ['Minneapolis', 'Foz', 'Londrina', 'Pinhais'],
#   'Atlanta': ['Minneapolis', 'New York', 'Curitiba', 'Atlanta'],
#   'Denver': ['Minneapolis', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Minneapolis', 'New York', 'Miami', 'Philadelphia'],
#   'Maringa': ['Minneapolis', 'New York', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Minneapolis', 'New York', 'Cleveland', 'Phoenix'],
#   'Albuquerque': ['Minneapolis',
#    'New York',
#    'Curitiba',
#    'Atlanta',
#    'Albuquerque']},
#  'Phoenix': {'Phoenix': ['Phoenix'],
#   'Cleveland': ['Phoenix', 'Cleveland'],
#   'Maringa': ['Phoenix', 'Maringa'],
#   'New York': ['Phoenix', 'Cleveland', 'New York'],
#   'Ponta Grossa': ['Phoenix', 'Cleveland', 'Ponta Grossa'],
#   'Albuquerque': ['Phoenix', 'Maringa', 'Albuquerque'],
#   'Tulsa': ['Phoenix', 'Maringa', 'Tulsa'],
#   'Chicago': ['Phoenix', 'Cleveland', 'New York', 'Chicago'],
#   'Curitiba': ['Phoenix', 'Cleveland', 'New York', 'Curitiba'],
#   'Miami': ['Phoenix', 'Cleveland', 'New York', 'Miami'],
#   'Minneapolis': ['Phoenix', 'Cleveland', 'New York', 'Minneapolis'],
#   'Foz': ['Phoenix', 'Cleveland', 'Ponta Grossa', 'Foz'],
#   'Londrina': ['Phoenix', 'Cleveland', 'Ponta Grossa', 'Londrina'],
#   'Sao Paulo': ['Phoenix', 'Cleveland', 'Ponta Grossa', 'Sao Paulo'],
#   'Atlanta': ['Phoenix', 'Maringa', 'Albuquerque', 'Atlanta'],
#   'Pinhais': ['Phoenix', 'Cleveland', 'New York', 'Chicago', 'Pinhais'],
#   'Denver': ['Phoenix', 'Cleveland', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Phoenix',
#    'Cleveland',
#    'New York',
#    'Miami',
#    'Philadelphia'],
#   'Boston': ['Phoenix', 'Cleveland', 'Ponta Grossa', 'Sao Paulo', 'Boston']},
#  'Ponta Grossa': {'Ponta Grossa': ['Ponta Grossa'],
#   'Cleveland': ['Ponta Grossa', 'Cleveland'],
#   'Foz': ['Ponta Grossa', 'Foz'],
#   'Londrina': ['Ponta Grossa', 'Londrina'],
#   'Sao Paulo': ['Ponta Grossa', 'Sao Paulo'],
#   'Maringa': ['Ponta Grossa', 'Cleveland', 'Maringa'],
#   'New York': ['Ponta Grossa', 'Cleveland', 'New York'],
#   'Phoenix': ['Ponta Grossa', 'Cleveland', 'Phoenix'],
#   'Minneapolis': ['Ponta Grossa', 'Foz', 'Minneapolis'],
#   'Pinhais': ['Ponta Grossa', 'Londrina', 'Pinhais'],
#   'Curitiba': ['Ponta Grossa', 'Sao Paulo', 'Curitiba'],
#   'Boston': ['Ponta Grossa', 'Sao Paulo', 'Boston'],
#   'Chicago': ['Ponta Grossa', 'Sao Paulo', 'Chicago'],
#   'Albuquerque': ['Ponta Grossa', 'Cleveland', 'Maringa', 'Albuquerque'],
#   'Tulsa': ['Ponta Grossa', 'Cleveland', 'Maringa', 'Tulsa'],
#   'Miami': ['Ponta Grossa', 'Cleveland', 'New York', 'Miami'],
#   'Atlanta': ['Ponta Grossa', 'Sao Paulo', 'Curitiba', 'Atlanta'],
#   'Denver': ['Ponta Grossa', 'Cleveland', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Ponta Grossa',
#    'Cleveland',
#    'New York',
#    'Miami',
#    'Philadelphia']},
#  'Boston': {'Boston': ['Boston'],
#   'Sao Paulo': ['Boston', 'Sao Paulo'],
#   'Curitiba': ['Boston', 'Sao Paulo', 'Curitiba'],
#   'Chicago': ['Boston', 'Sao Paulo', 'Chicago'],
#   'Foz': ['Boston', 'Sao Paulo', 'Foz'],
#   'Londrina': ['Boston', 'Sao Paulo', 'Londrina'],
#   'Minneapolis': ['Boston', 'Sao Paulo', 'Minneapolis'],
#   'Ponta Grossa': ['Boston', 'Sao Paulo', 'Ponta Grossa'],
#   'Atlanta': ['Boston', 'Sao Paulo', 'Curitiba', 'Atlanta'],
#   'Miami': ['Boston', 'Sao Paulo', 'Curitiba', 'Miami'],
#   'New York': ['Boston', 'Sao Paulo', 'Curitiba', 'New York'],
#   'Pinhais': ['Boston', 'Sao Paulo', 'Chicago', 'Pinhais'],
#   'Cleveland': ['Boston', 'Sao Paulo', 'Ponta Grossa', 'Cleveland'],
#   'Albuquerque': ['Boston', 'Sao Paulo', 'Curitiba', 'Atlanta', 'Albuquerque'],
#   'Philadelphia': ['Boston',
#    'Sao Paulo',
#    'Curitiba',
#    'Atlanta',
#    'Philadelphia'],
#   'Denver': ['Boston', 'Sao Paulo', 'Curitiba', 'Miami', 'Denver'],
#   'Tulsa': ['Boston', 'Sao Paulo', 'Curitiba', 'New York', 'Tulsa'],
#   'Maringa': ['Boston', 'Sao Paulo', 'Ponta Grossa', 'Cleveland', 'Maringa'],
#   'Phoenix': ['Boston', 'Sao Paulo', 'Ponta Grossa', 'Cleveland', 'Phoenix']},
#  'Tulsa': {'Tulsa': ['Tulsa'],
#   'Maringa': ['Tulsa', 'Maringa'],
#   'New York': ['Tulsa', 'New York'],
#   'Albuquerque': ['Tulsa', 'Maringa', 'Albuquerque'],
#   'Cleveland': ['Tulsa', 'Maringa', 'Cleveland'],
#   'Phoenix': ['Tulsa', 'Maringa', 'Phoenix'],
#   'Chicago': ['Tulsa', 'New York', 'Chicago'],
#   'Curitiba': ['Tulsa', 'New York', 'Curitiba'],
#   'Miami': ['Tulsa', 'New York', 'Miami'],
#   'Minneapolis': ['Tulsa', 'New York', 'Minneapolis'],
#   'Atlanta': ['Tulsa', 'Maringa', 'Albuquerque', 'Atlanta'],
#   'Ponta Grossa': ['Tulsa', 'Maringa', 'Cleveland', 'Ponta Grossa'],
#   'Pinhais': ['Tulsa', 'New York', 'Chicago', 'Pinhais'],
#   'Sao Paulo': ['Tulsa', 'New York', 'Chicago', 'Sao Paulo'],
#   'Denver': ['Tulsa', 'New York', 'Miami', 'Denver'],
#   'Philadelphia': ['Tulsa', 'New York', 'Miami', 'Philadelphia'],
#   'Foz': ['Tulsa', 'New York', 'Minneapolis', 'Foz'],
#   'Londrina': ['Tulsa', 'Maringa', 'Cleveland', 'Ponta Grossa', 'Londrina'],
#   'Boston': ['Tulsa', 'New York', 'Chicago', 'Sao Paulo', 'Boston']}}

# %%
nx.clustering(G)
# Out:
# {'Albuquerque': 0,
#  'Atlanta': 0,
#  'Chicago': 0.3333333333333333,
#  'New York': 0.13333333333333333,
#  'Pinhais': 0,
#  'Curitiba': 0.3,
#  'Miami': 0.16666666666666666,
#  'Sao Paulo': 0.23809523809523808,
#  'Londrina': 0.5,
#  'Foz': 0.6666666666666666,
#  'Maringa': 0.16666666666666666,
#  'Cleveland': 0.16666666666666666,
#  'Denver': 0,
#  'Philadelphia': 0,
#  'Minneapolis': 0.3333333333333333,
#  'Phoenix': 1.0,
#  'Ponta Grossa': 0.5,
#  'Boston': 0,
#  'Tulsa': 0}
